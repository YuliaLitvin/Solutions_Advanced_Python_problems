# %% [markdown]
# ## <center>Більше попереднього</center>
# На вхід до програми подається рядок тексту з натуральних чисел. З неї формується перелік чисел. Напишіть програму підрахунку кількості чисел, які більші за попередній у цьому списку числа.
#
# **Формат вхідних даних**
#
# На вхід до програми подається рядок тексту з розділених пробілами натуральних чисел.
#
# **Формат вихідних даних**
#
# Програма має вивести одне число – кількість елементів списку, більших за попередній.

# %%
a = input().split()
count = 0
for i in range(1, len(a)):
    if int(a[i]) > int(a[i - 1]):
        count += 1
print(count)
# Out:
# 1 1 3 2 2 1 1 1 1
# 1

# %% [markdown]
# ## <center>Добуток чисел</center>
# Напишіть програму для визначення, чи є числом твором двох чисел з цього набору, що виводить результат у вигляді відповіді «ТАК» або «НІ».
#
# **Формат вхідних даних**
#
# У першому рядку подається число n(0<n<1000) – кількість чисел у наборі. У наступних n рядках вводяться цілі числа, що становлять набір (можуть повторюватися). Потім слідує ціле число, яке є чи не є добутком двох якихось чисел із набору.
#
# **Формат вихідних даних**
#
# Програма повинна вивести «ТАК» або «НІ» відповідно до умови завдання.

# %%
nums = []
n = int(input())
res = 'НЕТ'
for i in range(n):
    nums.append(int(input()))
big = int(input())
for i in range(n):
    for j in range(n):
        if i != j:
            if nums[i] * nums[j] == big:
                res = 'ДА'
print(res)
# Out:
# 3
# 33
# 17
# 35
# 999
# НЕТ

# %% [markdown]
# ## <center>Кремнієва долина 🌶️🌶️</center>
# Штучний інтелект Антон, створений Гілфойлом, зламав мережу розумних холодильників. Тепер він використовує їх як сервери "Пегого дудочника". Допоможіть власнику фірми знайти всі заражені холодильники.
#
# Для кожного холодильника існує рядок з даними, що складається з малих літер і цифр, і якщо в ній присутнє слово "anton" (необов'язково літери, що поруч поруч, головна наявність послідовності літер), то холодильник заражений і потрібно вивести номер холодильника, нумерація починається з одиниці.
#
# **Формат вхідних даних**
#
# У першому рядку подається число n – кількість холодильників. У наступних n рядках вводяться рядки, що містять латинські малі літери та цифри, у кожному рядку від 5 до 100 символів.
#
# **Формат вихідних даних**
#
# Програма має вивести номери заражених холодильників через пропуск. Якщо таких холодильників немає, нічого не потрібно виводити.

# %%
s = int(input())
count = 1
result = []
for i in range(s):
    a = input()
    list = []
    for j in a:
        if j == 'a' and list == []:
            list.append(j)
        elif j == 'n' and list == ['a']:
              list.append(j)
        elif j == 't' and list == ['a', 'n']:
              list.append(j)
        elif j == 'o' and list == ['a', 'n', 't']:
              list.append(j)
        elif j == 'n' and list == ['a', 'n', 't', 'o']:
              list.append(j)
    list = ''.join(list)


    if 'anton' in list:
        result.append(count)
    count += 1
print(*result)
# Out:
# 6
# 222anton456
# a1n1t1o1n1
# 0000a0000n00t00000o000000n
# gylfole
# richard
# ant0n
# 1 2 3

# %% [markdown]
# ## <center>Роскомнагляд заборонив букву а 🌶️🌶️</center>
# Необхідно написати програму, яка реалізує алгоритм написання цієї пісні. Алгоритм виводить наприкінці речення наступну в алфавітному порядку букву, якщо вона зустрічається у рядку тексту, а черговий рядок відображає вже без цієї букви.
#
# **Формат вхідних даних**
#
# На вхід програмі подається одне слово, записане малими російськими літерами без літери "е".
#
# **Формат вихідних даних**
#
# Програма повинна вивести відповідно до зазначеного алгоритму рядка, кількість яких дорівнює кількості різних літер у рядку, що виходить шляхом конкатенації введеного слова та рядка "заборонив букву".

# %%
word = input() + ' запретил букву'
b = ['а', 'б', 'в', 'г', 'д', 'е', 'ж', 'з', 'и', 'й', 'к', 'л', 'м', 'н', 'о', 'п', 'р', 'с', 'т', 'у', 'ф', 'х', 'ц', 'ч', 'ш', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я']
for i in range(len(b)):
    if b[i] in word:
        print(word, b[i])
        word = word.replace(b[i], '')
        word = ' '.join(word.split())
# Out:
# тимур запретил букву а
# тимур запретил букву а запретил букву а
# тимур зпретил букву зпретил букву б
# тимур зпретил укву зпретил укву в
# тимур зпретил уку зпретил уку е
# тимур зпртил уку зпртил уку з
# тимур пртил уку пртил уку и
# тмур пртл уку пртл уку к
# тмур пртл уу пртл уу л
# тмур прт уу прт уу м
# тур прт уу прт уу п
# тур рт уу рт уу р
# ту т уу т уу т
# у уу уу у

# %% [markdown]
# ## <center>Зрушення у розвитку</center>
# На вхід до програми подається рядок тексту з натуральних чисел. З елементів рядка формується перелік чисел. Напишіть програму циклічного зсуву елементів списку праворуч, коли останній елемент стає першим, а решта зсувається на одну позицію вперед, у бік збільшення індексів.
#
# **Формат вхідних даних**
#
# На вхід до програми подається рядок тексту з розділених пробілами натуральних чисел.
#
# **Формат вихідних даних**
#
# Програма повинна вивести елементи зміненого списку із циклічним зсувом, розділяючи його елементи одним пробілом.

# %%
a = input().split()
a.insert(0, a[-1])
del a[-1]
print(*a)
# Out:
# 489 483 43 2 3 84 1 4 3 2 5 4 3 13
# 13 489 483 43 2 3 84 1 4 3 2 5 4 3
